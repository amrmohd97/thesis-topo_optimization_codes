# %%
import numpy as np
import netgen.geom2d as geom2d
from ngsolve import *
from ngsolve.webgui import Draw
from netgen.geom2d import SplineGeometry  # SplieGeometry to define a 2D mesh
# visualization stuff
from ngsolve.internal import *
# basic xfem functionality
#from xfem import *
from interpolations import InterpolateLevelSetToElems # function which interpolates a levelset function
import time
myMAXH = 0.1
EPS = myMAXH * 1e-6      #variable defining when a point is on the interface and when not

geo = SplineGeometry()

R = 2

## add a rectangle
geo.AddRectangle(p1=(-R,-R),
                 p2=(R,R),
                 bc="rectangle",
                 leftdomain=1,
                 rightdomain=0)
geo.SetMaterial (1, "outer") # give the domain the name "outer"
mesh = Mesh(geo.GenerateMesh(maxh=myMAXH)) # generate ngsolve mesh
mesh.nv,mesh.ne
# Out:
# (1942, 3722)

# %%
#Spaces and Functions

fes_state = H1(mesh, order=1)
fes_adj = H1(mesh, order=1)
fes_level = H1(mesh, order=1)

pwc = L2(mesh)   #piecewise constant space


## test and trial functions
u, v = fes_state.TnT()

p, q = fes_adj.TnT()

gfu = GridFunction(fes_state)
gfp = GridFunction(fes_adj)

gfud = GridFunction(fes_state)

psi = GridFunction(fes_level)
psi.Set(-1)

psides = GridFunction(fes_level)
psinew = GridFunction(fes_level)

# %%
# Forms And Solver
# constants for f_rhs and beta
f1 = 10
f2 = 1

alpha1=7
alpha2=2

beta1 = 1
beta2 = 1

# piecewise constant coefficient functions beta and f_rhs

beta = GridFunction(pwc)
beta.Set(beta1)

f_rhs = GridFunction(pwc)
f_rhs.Set(f1)

alpha = GridFunction(pwc)
alpha.Set(alpha1)
# bilinear form for state equation
B = BilinearForm(fes_state)
B += grad(u) * grad(v) * dx
B += alpha*u *v *dx

B_adj = BilinearForm(fes_adj)
B_adj += grad(p) * grad(q) * dx
B_adj += alpha*p * q * dx
L = LinearForm(fes_state)
L += f_rhs * v *dx


# solving
psides.Set(-1)
InterpolateLevelSetToElems(psides, beta1, beta2, beta, mesh, EPS)
InterpolateLevelSetToElems(psides, f1, f2, f_rhs, mesh, EPS)
InterpolateLevelSetToElems(psides, alpha1, alpha2, alpha, mesh, EPS)


B.Assemble()
L.Assemble()

inv = B.mat.Inverse( inverse="sparsecholesky") # inverse of bilinear form
gfu.vec.data = inv*L.vec

scene_u = Draw(gfu)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…

# %%
#Define destination function
a = 4.0/5.0
b = 2
f = CoefficientFunction( 0.1*( (sqrt((x - a)**2 + b * y**2) - 1) \
                * (sqrt((x + a)**2 + b * y**2) - 1) \
                * (sqrt(b * x**2 + (y - a)**2) - 1) \
                * (sqrt(b * x**2 + (y + a)**2) - 1) - 0.001) )

psides.Set(f)
InterpolateLevelSetToElems(psides, beta1, beta2, beta, mesh, EPS)
InterpolateLevelSetToElems(psides, f1, f2, f_rhs, mesh, EPS)
InterpolateLevelSetToElems(psides, alpha1, alpha2, alpha, mesh, EPS)

B.Assemble()
L.Assemble()
inv = B.mat.Inverse(inverse="sparsecholesky") # inverse of bilinear form

gfud.vec.data = inv*L.vec

Draw(gfud, mesh, 'gfud')
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
# BaseWebGuiScene

# %%
def SolvePDE(adjoint=False):
    #Newton(a, gfu, printing = False, maxerr = 3e-9)

    B.Assemble()
    L.Assemble()

    inv_state = B.mat.Inverse(inverse="sparsecholesky")

    # solve state equation
    gfu.vec.data = inv_state*L.vec

    if adjoint == True:
        # solve adjoint state equatoin
        duCost.Assemble()
        B_adj.Assemble()
        inv_adj = B_adj.mat.Inverse(inverse="sparsecholesky")
        gfp.vec.data = -inv_adj * duCost.vec
    scene_u.Redraw()

InterpolateLevelSetToElems(psi, beta1, beta2, beta, mesh, EPS)
InterpolateLevelSetToElems(psi, f1, f2, f_rhs, mesh, EPS)
InterpolateLevelSetToElems(psi, alpha1, alpha2, alpha, mesh, EPS)

SolvePDE()

# %%
# define the cost function
def Cost(u):
    return (u - gfud+10*x*y)**2*dx

# derivative of cost function
duCost = LinearForm(fes_adj)
duCost += 2*(gfu-gfud+10*x*y) * q * dx
print("initial cost = ", Integrate(Cost(gfu), mesh))
# Out:
# initial cost =  2847.4076688414466

# %%
#Topological Derivative

BetaPosNeg = 2 * beta2 * (beta1-beta2)/(beta1+beta2)    # factors in TD in positive part {x: \psi(x)>0} ={x: \beta(x) = \beta_2}
BetaNegPos = 2 * beta1 * (beta1-beta2)/(beta1+beta2)    # factors in TD in positive part {x: \psi(x)>0} ={x: \beta(x) = \beta_2}
FPosNeg = (alpha1-alpha2)-(f1-f2)

psinew.vec.data = psi.vec

## normalise psi in L2
normPsi = sqrt(Integrate(psi**2*dx, mesh))
psi.vec.data = 1/normPsi * psi.vec

# set level set function to data
InterpolateLevelSetToElems(psi, beta1, beta2, beta, mesh, EPS)
InterpolateLevelSetToElems(psi, f1, f2, f_rhs, mesh, EPS)
InterpolateLevelSetToElems(psi, alpha1, alpha2, f_rhs, mesh, EPS)

Redraw()

TD_node = GridFunction(fes_level)
#scene1 = Draw(TD_node, mesh, "TD_node")

TD_pwc = GridFunction(pwc)
#scene2 = Draw(TD_pwc, mesh, "TD_pwc")

TDPosNeg_pwc = GridFunction(pwc)
TDNegPos_pwc = GridFunction(pwc)

cutRatio = GridFunction(pwc)

# solve for current configuration
SolvePDE(adjoint=True)

# %%
iter_max = 200
converged = False

kappa = 0.1
costs = []
iterations = [] 
thetas = []
active_dofs = []
N = fes_state.ndof
theta_tolerance = 1.5
g_k = GridFunction(fes_level)


xm=0.
ym=0.
psi.Set( (x-xm)**2+(y-ym)**2-0.25**2)
psinew.vec.data= psi.vec
scene_u = Draw(gfu) ##DRAW
scene_psi = Draw(IfPos(psi,1,-1),mesh)

J = Integrate(Cost(gfu),mesh)

with TaskManager():

    for k in range(iter_max):
        print("================ iteration ", k, "===================")

        # copy new levelset data from psinew into psi
        psi.vec.data = psinew.vec
        scene_psi.Redraw()
        time.sleep(6)


        SolvePDE(adjoint=True)
        scene_u.Redraw()

        J_current = Integrate(Cost(gfu),mesh)

        print( Integrate( (gfu-gfud)**2*dx, mesh) )

        print("cost in beginning of iteration", k, ": Cost = ", J_current)

        # compute the piecewise constant topological derivative in each domain
        TDPosNeg_pwc.Set( BetaPosNeg * grad(gfu) * grad(gfp)  + FPosNeg*gfp )
        TDNegPos_pwc.Set( BetaNegPos * grad(gfu) * grad(gfp)  + FPosNeg*gfp )

        # compute the cut ratio of the interface elements
        InterpolateLevelSetToElems(psi, 1, 0, cutRatio, mesh, EPS)

        # compute the combined topological derivative using the cut ratio information
        for j in range(len(TD_pwc.vec)):
            TD_pwc.vec[j] = cutRatio.vec[j] * TDNegPos_pwc.vec[j] + (1-cutRatio.vec[j])*TDPosNeg_pwc.vec[j]

        TD_node.Set(TD_pwc)
        indices = []  

        for i in range(len((TD_node.vec))):
            if psi.vec[i] < 0 and TD_node.vec[i] > 0:
                indices.append(i)
            elif psi.vec[i] > 0 and TD_node.vec[i] < 0:
                indices.append(i)

        active_dofs.append(len(indices))
        iterations.append(k)
        print("Non optimals =" ,len(indices),"out of", N)

        if (len(indices) < int(0.005*N)) and (k > 4) :
            print("99.5% of elements satisfy optimality conditions, non optimal elements are",len(indices) ," out of ",N )
            break

        normTD = sqrt(Integrate(TD_node**2*dx, mesh)) # L2 norm of TD_node
        normPsi = sqrt(Integrate(psi**2*dx, mesh)) # L2 norm of psi
        
        arg_arc = Integrate(psi*TD_node,mesh)/(normTD*normPsi)
        theta_k = np.arccos(arg_arc)*180/np.pi
        print("Theta_k =",theta_k,"  degrees")
        thetas.append(theta_k)

        if theta_k < theta_tolerance:
            print("Theta Converged, theta = ", theta_k,"    degrees")
            break

        const_gk = Integrate(psi*TD_node,mesh)/(normPsi**2)
        g_k.Set( -1*(TD_node-const_gk*psi)   )
        TD_node.vec.data = 1/normTD * TD_node.vec # normalised TD_node
        psi.vec.data = 1/normPsi * psi.vec  # normalised psi


        
        linesearch = True

        for j in range(10):

            # update the level set function
            psinew.vec.data = (1-kappa)*psi.vec + kappa*TD_node.vec
            #psinew.vec.data = psi.vec - kappa *g_k.vec
            # update beta and f_rhs
            InterpolateLevelSetToElems(psinew, beta1, beta2, beta, mesh, EPS)
            InterpolateLevelSetToElems(psinew, f1, f2, f_rhs, mesh, EPS)
            InterpolateLevelSetToElems(psinew, alpha1, alpha2, alpha, mesh, EPS)

            # solve PDE without adjoint
            SolvePDE()

            Redraw(blocking=True)

            Jnew = Integrate(Cost(gfu), mesh)

            if Jnew > J_current:
                print("--------------------")
                print("-----line search ---")
                print("--------------------")
                kappa = kappa*0.8
                kappa = max(0.0001,kappa)
                print("kappa", kappa)
            else:
                kappa = 1.2*kappa
                break

        Redraw(blocking=True)
        print("----------- Jnew in  iteration ", k, " = ", Jnew, " (kappa = ", kappa, ")")
        print('')
        print("iter" + str(k) + ", Jnew = " + str(Jnew) + " (kappa = ", kappa, ")")
        kappa = min(1, kappa*1.2)

        print("end of iter " + str(k))
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
# ================ iteration  0 ===================
# 0.6066815543383566
# cost in beginning of iteration 0 : Cost =  2845.06089340809
# Non optimals = 984 out of 1942
# Theta_k = 89.83174444192464   degrees
# --------------------
# -----line search ---
# --------------------
# kappa 0.08000000000000002
# --------------------
# -----line search ---
# --------------------
# kappa 0.06400000000000002
# --------------------
# -----line search ---
# --------------------
# kappa 0.051200000000000016
# --------------------
# -----line search ---
# --------------------
# kappa 0.04096000000000002
# --------------------
# -----line search ---
# --------------------
# kappa 0.03276800000000001
# --------------------
# -----line search ---
# --------------------
# kappa 0.026214400000000013
# --------------------
# -----line search ---
# --------------------
# kappa 0.02097152000000001
# --------------------
# -----line search ---
# --------------------
# kappa 0.016777216000000008
# --------------------
# -----line search ---
# --------------------
# kappa 0.013421772800000007
# --------------------
# -----line search ---
# --------------------
# kappa 0.010737418240000006
# ----------- Jnew in  iteration  0  =  2849.0784629111067  (kappa =  0.010737418240000006 )
#
# iter0, Jnew = 2849.0784629111067 (kappa =  0.010737418240000006 )
# end of iter 0
# ================ iteration  1 ===================
# 4.626595183575783
# cost in beginning of iteration 1 : Cost =  2849.0784629111063
# Non optimals = 1034 out of 1942
# Theta_k = 91.94337646900425   degrees
# ----------- Jnew in  iteration  1  =  2849.0531368999086  (kappa =  0.015461882265600009 )
#
# iter1, Jnew = 2849.0531368999086 (kappa =  0.015461882265600009 )
# end of iter 1
# ================ iteration  2 ===================
# 4.604531838941859
# cost in beginning of iteration 2 : Cost =  2849.0531368999086
# Non optimals = 1034 out of 1942
# Theta_k = 91.18878186330772   degrees
# ----------- Jnew in  iteration  2  =  2849.0156508467862  (kappa =  0.022265110462464013 )
#
# iter2, Jnew = 2849.0156508467862 (kappa =  0.022265110462464013 )
# end of iter 2
# ================ iteration  3 ===================
# 4.572505902319787
# cost in beginning of iteration 3 : Cost =  2849.0156508467862
# Non optimals = 1032 out of 1942
# Theta_k = 90.09551297763412   degrees
# ----------- Jnew in  iteration  3  =  2848.9595892536327  (kappa =  0.03206175906594818 )
#
# iter3, Jnew = 2848.9595892536327 (kappa =  0.03206175906594818 )
# end of iter 3
# ================ iteration  4 ===================
# 4.526089244419789
# cost in beginning of iteration 4 : Cost =  2848.959589253633
# Non optimals = 1028 out of 1942
# Theta_k = 88.50824057768341   degrees
# ----------- Jnew in  iteration  4  =  2848.874001212941  (kappa =  0.04616893305496538 )
#
# iter4, Jnew = 2848.874001212941 (kappa =  0.04616893305496538 )
# end of iter 4
# ================ iteration  5 ===================
# 4.45943437364651
# cost in beginning of iteration 5 : Cost =  2848.87400121294
# Non optimals = 1023 out of 1942
# Theta_k = 86.19827927279417   degrees
# ----------- Jnew in  iteration  5  =  2848.733278239612  (kappa =  0.06648326359915015 )
#
# iter5, Jnew = 2848.733278239612 (kappa =  0.06648326359915015 )
# end of iter 5
# ================ iteration  6 ===================
# 4.3609746760402555
# cost in beginning of iteration 6 : Cost =  2848.733278239612
# Non optimals = 1015 out of 1942
# Theta_k = 82.82831627073725   degrees
# ----------- Jnew in  iteration  6  =  2848.4616375806295  (kappa =  0.0957358995827762 )
#
# iter6, Jnew = 2848.4616375806295 (kappa =  0.0957358995827762 )
# end of iter 6
# ================ iteration  7 ===================
# 4.199766868752146
# cost in beginning of iteration 7 : Cost =  2848.461637580629
# Non optimals = 1005 out of 1942
# Theta_k = 77.90512169946952   degrees
# ----------- Jnew in  iteration  7  =  2847.7177712779444  (kappa =  0.1378596953991977 )
#
# iter7, Jnew = 2847.7177712779444 (kappa =  0.1378596953991977 )
# end of iter 7
# ================ iteration  8 ===================
# 3.8901174344817844
# cost in beginning of iteration 8 : Cost =  2847.717771277944
# Non optimals = 979 out of 1942
# Theta_k = 70.7254216399856   degrees
# ----------- Jnew in  iteration  8  =  2840.8651407165653  (kappa =  0.1985179613748447 )
#
# iter8, Jnew = 2840.8651407165653 (kappa =  0.1985179613748447 )
# end of iter 8
# ================ iteration  9 ===================
# 2.84565549148171
# cost in beginning of iteration 9 : Cost =  2840.865140716565
# Non optimals = 894 out of 1942
# Theta_k = 59.784262028181345   degrees
# ----------- Jnew in  iteration  9  =  2754.0248865523663  (kappa =  0.28586586437977635 )
#
# iter9, Jnew = 2754.0248865523663 (kappa =  0.28586586437977635 )
# end of iter 9
# ================ iteration  10 ===================
# 1.6994432152645933
# cost in beginning of iteration 10 : Cost =  2754.0248865523663
# Non optimals = 411 out of 1942
# Theta_k = 25.6386585519308   degrees
# ----------- Jnew in  iteration  10  =  2738.0604713257785  (kappa =  0.4116468447068779 )
#
# iter10, Jnew = 2738.0604713257785 (kappa =  0.4116468447068779 )
# end of iter 10
# ================ iteration  11 ===================
# 2.029214578150599
# cost in beginning of iteration 11 : Cost =  2738.0604713257785
# Non optimals = 160 out of 1942
# Theta_k = 12.232059511305572   degrees
# ----------- Jnew in  iteration  11  =  2735.7298268878812  (kappa =  0.5927714563779041 )
#
# iter11, Jnew = 2735.7298268878812 (kappa =  0.5927714563779041 )
# end of iter 11
# ================ iteration  12 ===================
# 2.1634089497839675
# cost in beginning of iteration 12 : Cost =  2735.7298268878817
# Non optimals = 59 out of 1942
# Theta_k = 5.808058942716852   degrees
# ----------- Jnew in  iteration  12  =  2735.3174468680427  (kappa =  0.8535908971841818 )
#
# iter12, Jnew = 2735.3174468680427 (kappa =  0.8535908971841818 )
# end of iter 12
# ================ iteration  13 ===================
# 2.194906363607147
# cost in beginning of iteration 13 : Cost =  2735.317446868042
# Non optimals = 14 out of 1942
# Theta_k = 1.598087645165751   degrees
# ----------- Jnew in  iteration  13  =  2735.292820187547  (kappa =  1.2 )
#
# iter13, Jnew = 2735.292820187547 (kappa =  1.2 )
# end of iter 13
# ================ iteration  14 ===================
# 2.204223257168465
# cost in beginning of iteration 14 : Cost =  2735.2928201875466
# Non optimals = 0 out of 1942
# 99.5% of elements satisfy optimality conditions, non optimal elements are 0  out of  1942

# %%
import csv

# Save data to CSV
with open('Non_opt_pnts_REF_alpha12_convex_comb.csv', 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['Iterations', 'Non-Optimal Points'])
    for i in range(len(iterations)):
        csvwriter.writerow([iterations[i], active_dofs[i]])

print("Data saved to data.csv")
# Out:
# Data saved to data.csv

# %%
import csv

# Save data to CSV
with open('Thetas_REF_alpha12_grad_desc.csv', 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['Iterations', 'Theta'])
    for i in range(len(iterations)-1):
        csvwriter.writerow([iterations[i], thetas[i]])

print("Data saved to data.csv")
# Out:
# Data saved to data.csv
