# %%
import numpy as np
import netgen.geom2d as geom2d
from ngsolve import *
from ngsolve.internal import *
from ngsolve.webgui import Draw

from interpolations import InterpolateLevelSetToElems # function which interpolates a levelset function


myMAXH = 0.025
EPS = myMAXH * 1e-6
epsi = 1e-3

geo = geom2d.SplineGeometry()
pnums = [geo.AddPoint (x,y,maxh=0.1) for x,y in [(0,0), (2,0), (2,1), (0,1)] ]
for p1,p2,bc in [(0,1,"bot"), (1,2,"right"), (2,3,"top"), (3,0,"left")]:
     geo.Append(["line", pnums[p1], pnums[p2]], bc=bc)
mesh = Mesh(geo.GenerateMesh(maxh=myMAXH))

# Elasticity constants and functions
E, nu = 1, 0.3 
ell = 100
mu  = E / 2 / (1+nu)
lam_star = (E*nu)/((1+nu)*(1-2*nu)) 
lam = (2*mu*lam_star)/(lam_star+2*mu)

def Stress(strain):
    return 2*mu*strain + lam*Trace(strain)*Id(2)
def Eps ( u ) :
    return 1/2 * ( Grad(u)+Grad(u).trans )
#Spaces
fes = VectorH1(mesh, order=1,dirichlet="left",dim=1)
fes_grad = H1(mesh, order=1,dim=4)
fes_level = H1(mesh, order=1,dim=1)
pwc = L2(mesh)   #piecewise constant space

# Load Point determination
load_point_index = 0
L_test = LinearForm(fes)
L_test.Assemble()    

for v in mesh.vertices:
           
    if v.point[0] == 2 and abs(v.point[1]-0.5) < epsi: # Right boundary && midpoint
                load_point_index = int(v.nr+(len(L_test.vec)/2))  # Convert the index part to integer
                print("Load Point ", v.point, v)
                print("Load Point Index (for y-component of the force):", load_point_index)
#Constants for alpha 
alpha_in = 1
alpha_out = epsi #"Soft Material" Approximation 

#Level Set Function 
psi = GridFunction(fes_level)
psinew = GridFunction(fes_level)
psi.Set(-1)

#Piecewise constant coefficient function alpha
alpha = GridFunction(pwc)
alpha.Set(alpha_in)

u,v = fes.TnT()
gfu = GridFunction(fes) #vector H1  

TD_node = GridFunction(fes_level) #Scalar H1
g_k = GridFunction(fes_level)

TD_pwc = GridFunction(pwc)  #Scalar PWC
TDPosNeg_pwc = GridFunction(pwc) 
TDNegPos_pwc = GridFunction(pwc) 
cutRatio = GridFunction(pwc) 
#Formes and solver

B = BilinearForm(alpha*InnerProduct(Stress(Eps((u))), Eps((v))).Compile()*dx)   
L = LinearForm(fes)



def SolvePDE():
    InterpolateLevelSetToElems(psi, alpha_in, alpha_out, alpha, mesh, EPS) 

    B.Assemble()
    L.Assemble()
    L.vec[load_point_index]=-1 
    inv_state = B.mat.Inverse(fes.FreeDofs(), inverse="sparsecholesky")
  
    # solve state equation
    gfu.vec.data = inv_state*L.vec
SolvePDE()
Draw(gfu)
N = fes_level.ndof
print('dofs=',N,mesh.nv,mesh.ne)
# Out:
# Load Point  (2.0, 0.5) V102
# Load Point Index (for y-component of the force): 3916
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
# dofs= 3814 3814 7386

# %%
#MAIN LOOP

costs = []
iterations = [] 
thetas = []
active_dofs = []

psi.Set( (x-1)**2+(y-0.5)**2-0.25**2)
#psi.Set(-1)
InterpolateLevelSetToElems(psi, alpha_in, alpha_out, alpha, mesh, EPS)
psinew.vec.data= psi.vec

SolvePDE()

# TD Constants:
alpha_in = 1 
alpha_out = epsi
r_in = alpha_out/alpha_in
r_out = alpha_in/alpha_out
kappa_td=(lam+3*mu)/(lam+mu)

const_NegPos =  alpha_in* ( (r_in-1)/(kappa_td*r_in+1) )*( (kappa_td+1)  / 2 )    #multiplied by -ve 1 

const_PosNeg = -alpha_out*( (r_out-1)/(kappa_td*r_out+1) )*((kappa_td+1) / 2 )

const_in_NegPos = ( (r_in-1)*(kappa_td-2)/(kappa_td+2*r_in-1) )

const_in_PosNeg= ( (r_out-1)*(kappa_td-2)/(kappa_td+2*r_out-1) )

kappa=0.5
kappa_max = 1
iter_max = 300

vol = GridFunction(pwc)
InterpolateLevelSetToElems(psi, 1, 0, vol, mesh, EPS)
compliance_cf= InnerProduct ( alpha*Stress(Eps(gfu)) , Eps(gfu)   )
j = Integrate(compliance_cf, mesh) + ell*Integrate(vol,mesh)
print("Cost before loop = " ,j)
for i in range(4):
    costs.append(j)

scene_u = Draw(gfu) ##DRAW
scene_psi = Draw(IfPos(psi,1,-1),mesh)
theta_k = 130
theta_tolerance = 1.5


with TaskManager():

    for k in range(iter_max):


        print("================ iteration ", k, "===================")
        psi.vec.data=psinew.vec 
        scene_psi.Redraw()
        InterpolateLevelSetToElems(psi, alpha_in, alpha_out, alpha, mesh, EPS)
        InterpolateLevelSetToElems(psi, 1, 0, vol, mesh, EPS)
        InterpolateLevelSetToElems(psi, 1, 0, cutRatio, mesh, EPS) # compute the cut ratio of the interface elements

        SolvePDE()
        scene_u.Redraw()

        compliance_cf= InnerProduct ( alpha*Stress(Eps(gfu)) , Eps(gfu)   )
        J_current = Integrate(compliance_cf, mesh) + ell*Integrate(vol,mesh)
        costs.append(J_current)
        last_five_costs = costs[-5:]
        max_last_five = max(last_five_costs) #  for the line search
        print("cost in beginning of iteration", k, ": Cost = ", J_current)
        print("Maximum cost in last 5 iterations = ",max_last_five) 

        #Topological derivative 
 
        trm1= 2*InnerProduct(Stress(Eps(gfu)), Eps(gfu))    
        trm2=Trace(Stress(Eps(gfu)))*Trace(Eps(gfu))
        TDPosNeg_pwc.Set( const_PosNeg * (trm1+const_in_PosNeg*trm2)  + ell )                        
        TDNegPos_pwc.Set( const_NegPos * (trm1+const_in_NegPos*trm2)  + ell )
        for j in range(len(TD_pwc.vec)):
            TD_pwc.vec[j] = cutRatio.vec[j] * TDNegPos_pwc.vec[j] + (1-cutRatio.vec[j])*TDPosNeg_pwc.vec[j]

        TD_node.Set(TD_pwc)


        normTD = sqrt(Integrate(TD_node**2*dx, mesh)) # L2 norm of TD_node
        normPsi = sqrt(Integrate(psi**2*dx, mesh)) # L2 norm of psi
       
        const_gk = Integrate(psi*TD_node,mesh)/(normPsi**2)
        g_k.Set( -1*(TD_node-const_gk*psi)   )  
        
      #  TD_node.vec.data = (1/(normTD)) * TD_node.vec # normalised TD_node
    #    psi.vec.data = 1/normPsi * psi.vec  # normalised psi
        ##########################
        arg_arc = Integrate(psi*TD_node,mesh)/(normTD*normPsi)
        theta_k = np.arccos(arg_arc)*180/np.pi
        print("Theta_k =",theta_k,"  degrees")
        thetas.append(theta_k)
        
        if theta_k < theta_tolerance:
            break

        indices = []
        for i in range(N):
                if (psi.vec[i] < 0) and (TD_node.vec[i] > 0):#In Omega  -DJ>0 mm DJ < 0 , NOT optimal
                    indices.append(i)
                elif(psi.vec[i] > 0) and (TD_node.vec[i] < 0): #OUT Omega
                    indices.append(i)
        active_dofs.append(len(indices))
        iterations.append(k)
        
        for j in range(10):

            # update the level set function
            psinew.vec.data = (1-kappa)*psi.vec + kappa*TD_node.vec
            #psinew.vec.data = psi.vec - kappa *g_k.vec
            # update beta and f_rhs
            InterpolateLevelSetToElems(psinew, 1, 0, vol, mesh, EPS)
            InterpolateLevelSetToElems(psinew, alpha_in, alpha_out, alpha, mesh, EPS)

            # solve PDE without adjoint
            SolvePDE()

            Redraw(blocking=True)
            compliance_cf= InnerProduct ( alpha*Stress(Eps(gfu)) , Eps(gfu)   )
            J_new = Integrate(compliance_cf, mesh) + ell*Integrate(vol,mesh)

            if J_new > max_last_five:
                print("--------------------")
                print("-----line search ---")
                print("--------------------")
                kappa = kappa*0.5
                kappa = max(0.01,kappa) 
                print("kappa", kappa)
            else:
                kappa = min(kappa_max, kappa*1.3)
                print("Step accepted , size increased from " , kappa/1.3 ,"to ",kappa)                
                break
        #########################
        # kappa = min(kappa,kappa_max)
        # psinew.vec.data = (1-kappa)*psi.vec + kappa*TD_node.vec
        # InterpolateLevelSetToElems(psinew, 1, 0, vol, mesh, EPS)
        # InterpolateLevelSetToElems(psinew, alpha_in, alpha_out, alpha, mesh, EPS)

        # SolvePDE()
        # compliance_cf= InnerProduct ( alpha*Stress(Eps(gfu)) , Eps(gfu)   )
        # J_new = Integrate(compliance_cf, mesh) + ell*Integrate(vol,mesh)
        # print("for step size kappa = ",kappa,"new cost =",J_new)
        # if J_new <  max_last_five:
        #     psi.vec.data = psinew.vec
        #     scene_psi.Redraw()

        #     kappa = 1.2*kappa
        #     print("Step accepted , size increased from " , kappa/1.2 ,"to ",kappa)
        # else:
        #     kappa = 0.8*kappa 
        #     kappa = max(0.01,kappa)
        #     print("Step rejected , size decreased from " , kappa/0.8 ,"to ",kappa) 


        #kappa = min(1, kappa*1.2)

        print("end of iter " + str(k))
# Out:
# Cost before loop =  36960.27009816243
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
# ================ iteration  0 ===================
# cost in beginning of iteration 0 : Cost =  36960.270099394766
# Maximum cost in last 5 iterations =  36960.270099394766
# Theta_k = 125.71068759217205   degrees
# --------------------
# -----line search ---
# --------------------
# kappa 0.25
# --------------------
# -----line search ---
# --------------------
# kappa 0.125
# --------------------
# -----line search ---
# --------------------
# kappa 0.0625
# --------------------
# -----line search ---
# --------------------
# kappa 0.03125
# --------------------
# -----line search ---
# --------------------
# kappa 0.015625
# --------------------
# -----line search ---
# --------------------
# kappa 0.01
# --------------------
# -----line search ---
# --------------------
# kappa 0.01
# --------------------
# -----line search ---
# --------------------
# kappa 0.01
# --------------------
# -----line search ---
# --------------------
# kappa 0.01
# --------------------
# -----line search ---
# --------------------
# kappa 0.01
# end of iter 0
# ================ iteration  1 ===================
# cost in beginning of iteration 1 : Cost =  227.88553938736857
# Maximum cost in last 5 iterations =  36960.270099394766
# Theta_k = 57.359355161206494   degrees
# Step accepted , size increased from  0.01 to  0.013000000000000001
# end of iter 1
# ================ iteration  2 ===================
# cost in beginning of iteration 2 : Cost =  225.79750133261797
# Maximum cost in last 5 iterations =  36960.270099394766
# Theta_k = 57.18655223795682   degrees
# Step accepted , size increased from  0.013000000000000001 to  0.016900000000000002
# end of iter 2
# ================ iteration  3 ===================
# cost in beginning of iteration 3 : Cost =  224.85205782587983
# Maximum cost in last 5 iterations =  36960.270099394766
# Theta_k = 57.023006457136184   degrees
# Step accepted , size increased from  0.016900000000000002 to  0.021970000000000003
# end of iter 3
# ================ iteration  4 ===================
# cost in beginning of iteration 4 : Cost =  224.07948267271547
# Maximum cost in last 5 iterations =  36960.270099394766
# Theta_k = 56.835448371938526   degrees
# Step accepted , size increased from  0.021970000000000003 to  0.028561000000000007
# end of iter 4
# ================ iteration  5 ===================
# cost in beginning of iteration 5 : Cost =  223.26027713168276
# Maximum cost in last 5 iterations =  227.88553938736857
# Theta_k = 56.601397802493246   degrees
# Step accepted , size increased from  0.028561000000000007 to  0.03712930000000001
# end of iter 5
# ================ iteration  6 ===================
# cost in beginning of iteration 6 : Cost =  222.33615772637592
# Maximum cost in last 5 iterations =  225.79750133261797
# Theta_k = 56.29548559938663   degrees
# Step accepted , size increased from  0.03712930000000001 to  0.048268090000000013
# end of iter 6
# ================ iteration  7 ===================
# cost in beginning of iteration 7 : Cost =  221.16319465932315
# Maximum cost in last 5 iterations =  224.85205782587983
# Theta_k = 55.88671448311132   degrees
# Step accepted , size increased from  0.048268090000000013 to  0.06274851700000002
# end of iter 7
# ================ iteration  8 ===================
# cost in beginning of iteration 8 : Cost =  219.7276463068776
# Maximum cost in last 5 iterations =  224.07948267271547
# Theta_k = 55.32783030472916   degrees
# Step accepted , size increased from  0.06274851700000002 to  0.08157307210000003
# end of iter 8
# ================ iteration  9 ===================
# cost in beginning of iteration 9 : Cost =  217.88322272588624
# Maximum cost in last 5 iterations =  223.26027713168276
# Theta_k = 54.55033847658868   degrees
# Step accepted , size increased from  0.08157307210000003 to  0.10604499373000005
# end of iter 9
# ================ iteration  10 ===================
# cost in beginning of iteration 10 : Cost =  215.03415466772026
# Maximum cost in last 5 iterations =  222.33615772637592
# Theta_k = 53.43698614217065   degrees
# Step accepted , size increased from  0.10604499373000005 to  0.13785849184900006
# end of iter 10
# ================ iteration  11 ===================
# cost in beginning of iteration 11 : Cost =  210.8191383278315
# Maximum cost in last 5 iterations =  221.16319465932315
# Theta_k = 51.74013506553486   degrees
# Step accepted , size increased from  0.13785849184900006 to  0.1792160394037001
# end of iter 11
# ================ iteration  12 ===================
# cost in beginning of iteration 12 : Cost =  203.89123651258853
# Maximum cost in last 5 iterations =  219.7276463068776
# Theta_k = 49.004378605467245   degrees
# Step accepted , size increased from  0.1792160394037001 to  0.23298085122481013
# end of iter 12
# ================ iteration  13 ===================
# cost in beginning of iteration 13 : Cost =  210.6280999800161
# Maximum cost in last 5 iterations =  217.88322272588624
# Theta_k = 74.21850555584717   degrees
# Step accepted , size increased from  0.23298085122481013 to  0.3028751065922532
# end of iter 13
# ================ iteration  14 ===================
# cost in beginning of iteration 14 : Cost =  185.22499276242988
# Maximum cost in last 5 iterations =  215.03415466772026
# Theta_k = 41.83861995548808   degrees
# Step accepted , size increased from  0.3028751065922532 to  0.39373763856992916
# end of iter 14
# ================ iteration  15 ===================
# cost in beginning of iteration 15 : Cost =  173.91795618753997
# Maximum cost in last 5 iterations =  210.8191383278315
# Theta_k = 37.0004220626365   degrees
# Step accepted , size increased from  0.3937376385699291 to  0.5118589301409079
# end of iter 15
# ================ iteration  16 ===================
# cost in beginning of iteration 16 : Cost =  163.68211595699864
# Maximum cost in last 5 iterations =  210.6280999800161
# Theta_k = 25.342613087485855   degrees
# Step accepted , size increased from  0.5118589301409079 to  0.6654166091831802
# end of iter 16
# ================ iteration  17 ===================
# cost in beginning of iteration 17 : Cost =  158.3459380511918
# Maximum cost in last 5 iterations =  210.6280999800161
# Theta_k = 15.859768907724842   degrees
# Step accepted , size increased from  0.6654166091831802 to  0.8650415919381343
# end of iter 17
# ================ iteration  18 ===================
# cost in beginning of iteration 18 : Cost =  155.16687399647031
# Maximum cost in last 5 iterations =  185.22499276242988
# Theta_k = 7.4819289785428245   degrees
# Step accepted , size increased from  0.7692307692307692 to  1
# end of iter 18
# ================ iteration  19 ===================
# cost in beginning of iteration 19 : Cost =  154.0932683418368
# Maximum cost in last 5 iterations =  173.91795618753997
# Theta_k = 3.729230571525681   degrees
# Step accepted , size increased from  0.7692307692307692 to  1
# end of iter 19
# ================ iteration  20 ===================
# cost in beginning of iteration 20 : Cost =  153.66847583032194
# Maximum cost in last 5 iterations =  163.68211595699864
# Theta_k = 2.236041644469673   degrees
# Step accepted , size increased from  0.7692307692307692 to  1
# end of iter 20
# ================ iteration  21 ===================
# cost in beginning of iteration 21 : Cost =  153.46625374638896
# Maximum cost in last 5 iterations =  158.3459380511918
# Theta_k = 1.947727302618219   degrees
# Step accepted , size increased from  0.7692307692307692 to  1
# end of iter 21
# ================ iteration  22 ===================
# cost in beginning of iteration 22 : Cost =  153.36447273524894
# Maximum cost in last 5 iterations =  155.16687399647031
# Theta_k = 1.805188121739034   degrees
# Step accepted , size increased from  0.7692307692307692 to  1
# end of iter 22
# ================ iteration  23 ===================
# cost in beginning of iteration 23 : Cost =  153.25961662770817
# Maximum cost in last 5 iterations =  154.0932683418368
# Theta_k = 1.7646685997725988   degrees
# Step accepted , size increased from  0.7692307692307692 to  1
# end of iter 23
# ================ iteration  24 ===================
# cost in beginning of iteration 24 : Cost =  153.1816488763605
# Maximum cost in last 5 iterations =  153.66847583032194
# Theta_k = 1.605770693168121   degrees
# Step accepted , size increased from  0.7692307692307692 to  1
# end of iter 24
# ================ iteration  25 ===================
# cost in beginning of iteration 25 : Cost =  153.12902918430973
# Maximum cost in last 5 iterations =  153.46625374638896
# Theta_k = 1.4748479839600648   degrees

# %%
 Draw(IfPos(psi,1,-1),mesh)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
# BaseWebGuiScene

# %%
import matplotlib.pyplot as plt# Figure 1: Norm vs Iteration
plt.figure()
plt.plot(iterations, active_dofs, label='Active Dofs')
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('Active Dofs', fontsize=14)
plt.title('Count of non-optimal DOFs vs Iteration', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend()
plt.grid(True)
plt.savefig("active_dofs_canti_circ.png")
plt.show()

# %%
import matplotlib.pyplot as plt# Figure 1: Norm vs Iteration
plt.plot(iterations, thetas[0:-1], label='Theta')
plt.xlabel('Iteration',fontsize=14)
plt.ylabel('Theta',fontsize=14)
plt.title('Theta criterion vs Iteration',fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend()
plt.grid(True)
plt.savefig("theta_canti_circ.png")
plt.show()
