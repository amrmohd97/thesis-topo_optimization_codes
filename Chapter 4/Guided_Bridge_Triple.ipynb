# %%
import numpy as np
import netgen.geom2d as geom2d
from ngsolve import *
from ngsolve.webgui import Draw
# visualization stuff
from ngsolve.internal import *
from interpolations import InterpolateLevelSetToElems # function which interpolates a levelset function

#Constants and geometry

myMAXH = 0.05/2
EPS = myMAXH * 1e-6
epsi = 1e-3

geo = geom2d.SplineGeometry()

pnums = [geo.AddPoint (x,y,maxh=0.1) for x,y in [(0,0), (0.1,0),(1.9,0),(2,0), (2,1.2), (0,1.2)] ]
for p1,p2,bc in [(0,1,"roller_left"),(1,2,"bot") ,(2,3,"roller_right"),(3,4,"right"), (4,5,"top"), (5,0,"left")]:
        geo.Append(["line", pnums[p1], pnums[p2]], bc=bc)
mesh = Mesh(geo.GenerateMesh(maxh=myMAXH))
E, nu = 1, 0.3 
ell = 120
mu  = E / 2 / (1+nu)
lam = E * nu / ((1+nu)*(1-2*nu))
# TD Constants: 

alpha_in = 1 
alpha_out = epsi
r_in = alpha_out/alpha_in
r_out = alpha_in/alpha_out
kappa_td=(lam+3*mu)/(lam+mu)

const_NegPos =  alpha_in* ( (r_in-1)/(kappa_td*r_in+1) )*( (kappa_td+1)  / 2 )    #multiplied by -ve 1 

const_PosNeg = -alpha_out*( (r_out-1)/(kappa_td*r_out+1) )*((kappa_td+1) / 2 )

const_in_NegPos = ( (r_in-1)*(kappa_td-2)/(kappa_td+2*r_in-1) )

const_in_PosNeg= ( (r_out-1)*(kappa_td-2)/(kappa_td+2*r_out-1) )


#Functions 

def Stress(strain):
    return 2*mu*strain + lam*Trace(strain)*Id(2)

def Eps ( u ) :
    return 1/2 * ( Grad(u)+Grad(u).trans )

#SPaces
# fes = VectorH1(mesh, order=1,dirichlet="roller_left|roller_right")
# fes_grad = VectorH1(mesh, order=1,dim=2)
fes = VectorH1(mesh, order=1,dirichlet="roller_left|roller_right",dim=1)
fes_grad = H1(mesh, order=1,dim=4)
fes_level = H1(mesh, order=1,dim=1)
pwc = L2(mesh)   #piecewise constant space

L_test = LinearForm(fes)
load_point_index = []
for v in mesh.vertices:
      if (v.point[1]==0)and(abs(v.point[0]-0.5) < 0.001 or abs(v.point[0]-1) < 0.001 or abs(v.point[0]-1.5) < 0.001):
            print("Load Point",v,v.nr)
            load_point_index.append(int(v.nr+(len(L_test.vec)/2)) )  # Convert the index part to integer

print(load_point_index) 

#Constants for alpha 
alpha_in = 1
alpha_out = epsi #"Soft Material" Approximation 

#Level Set Function 
psi = GridFunction(fes_level)
psinew = GridFunction(fes_level)
psi.Set(-1)

#Piecewise constant coefficient function alpha
alpha = GridFunction(pwc)
alpha.Set(alpha_in)

u,v = fes.TnT()
gfu = GridFunction(fes) #vector H1  

TD_node = GridFunction(fes_level) #Scalar H1
g_k = GridFunction(fes_level)

TD_pwc = GridFunction(pwc)  #Scalar PWC
TDPosNeg_pwc = GridFunction(pwc) 
TDNegPos_pwc = GridFunction(pwc) 
cutRatio = GridFunction(pwc) 
#Formes and solver

B = BilinearForm(alpha*InnerProduct(Stress(Eps((u))), Eps((v))).Compile()*dx)   
L = LinearForm(fes)


def SolvePDE(adjoint=False):
    #Newton(a, gfu, printing = False, maxerr = 3e-9)

    B.Assemble()
    L.Assemble()
    for v in load_point_index:
        L.vec[v]=-1 

    inv_state = B.mat.Inverse(fes.FreeDofs(), inverse="sparsecholesky")

    # solve state equation
    gfu.vec.data = inv_state*L.vec

InterpolateLevelSetToElems(psi, alpha_in, alpha_out, alpha, mesh, EPS)

SolvePDE()
Draw(gfu)
mesh.nv,mesh.ne
# Out:
# Load Point V24 24
# Load Point V44 44
# Load Point V64 64
# [4610, 4630, 4650]
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
# (4586, 8914)

# %%
#MAIN LOOP
N = fes_level.ndof

costs = []
iterations = [] 
thetas = []
active_dofs = []

#psi.Set(-1)
psi.Set( (x-1)**2+(y-0.5)**2-0.25**2)

InterpolateLevelSetToElems(psi, alpha_in, alpha_out, alpha, mesh, EPS)
psinew.vec.data= psi.vec

SolvePDE()

# TD Constants:
alpha_in = 1 
alpha_out = epsi
r_in = alpha_out/alpha_in
r_out = alpha_in/alpha_out
kappa_td=(lam+3*mu)/(lam+mu)

const_NegPos =  alpha_in* ( (r_in-1)/(kappa_td*r_in+1) )*( (kappa_td+1)  / 2 )    #multiplied by -ve 1 

const_PosNeg = -alpha_out*( (r_out-1)/(kappa_td*r_out+1) )*((kappa_td+1) / 2 )

const_in_NegPos = ( (r_in-1)*(kappa_td-2)/(kappa_td+2*r_in-1) )

const_in_PosNeg= ( (r_out-1)*(kappa_td-2)/(kappa_td+2*r_out-1) )

kappa=0.5
kappa_max = 1
iter_max = 150

vol = GridFunction(pwc)
InterpolateLevelSetToElems(psi, 1, 0, vol, mesh, EPS)
compliance_cf= InnerProduct ( alpha*Stress(Eps(gfu)) , Eps(gfu)   )
j = Integrate(compliance_cf, mesh) + ell*Integrate(vol,mesh)
print("Cost before loop = " ,j)
for i in range(4):
    costs.append(j)

scene_u = Draw(gfu) ##DRAW
scene_psi = Draw(IfPos(psi,1,-1),mesh)
theta_k = 130
theta_tolerance = 1.5


with TaskManager():

    for k in range(iter_max):


        print("================ iteration ", k, "===================")
        psi.vec.data=psinew.vec 
        scene_psi.Redraw()
        InterpolateLevelSetToElems(psi, alpha_in, alpha_out, alpha, mesh, EPS)
        InterpolateLevelSetToElems(psi, 1, 0, vol, mesh, EPS)
        InterpolateLevelSetToElems(psi, 1, 0, cutRatio, mesh, EPS) # compute the cut ratio of the interface elements

        SolvePDE()
        scene_u.Redraw()

        compliance_cf= InnerProduct ( alpha*Stress(Eps(gfu)) , Eps(gfu)   )
        J_current = Integrate(compliance_cf, mesh) + ell*Integrate(vol,mesh)
        costs.append(J_current)
        last_five_costs = costs[-5:]
        max_last_five = max(last_five_costs) #  for the line search
        print("cost in beginning of iteration", k, ": Cost = ", J_current)
        print("Maximum cost in last 5 iterations = ",max_last_five) 

        #Topological derivative 
 
        trm1= 2*InnerProduct(Stress(Eps(gfu)), Eps(gfu))    
        trm2=Trace(Stress(Eps(gfu)))*Trace(Eps(gfu))
        TDPosNeg_pwc.Set( const_PosNeg * (trm1+const_in_PosNeg*trm2)  + ell )                        
        TDNegPos_pwc.Set( const_NegPos * (trm1+const_in_NegPos*trm2)  + ell )
        for j in range(len(TD_pwc.vec)):
            TD_pwc.vec[j] = cutRatio.vec[j] * TDNegPos_pwc.vec[j] + (1-cutRatio.vec[j])*TDPosNeg_pwc.vec[j]

        TD_node.Set(TD_pwc)


        normTD = sqrt(Integrate(TD_node**2*dx, mesh)) # L2 norm of TD_node
        normPsi = sqrt(Integrate(psi**2*dx, mesh)) # L2 norm of psi
       
        const_gk = Integrate(psi*TD_node,mesh)/(normPsi**2)
        g_k.Set( -1*(TD_node-const_gk*psi)   )  
        
        TD_node.vec.data = (1/(normTD)) * TD_node.vec # normalised TD_node
        psi.vec.data = 1/normPsi * psi.vec  # normalised psi
        ##########################
        arg_arc = Integrate(psi*TD_node,mesh)/(normTD*normPsi)
        theta_k = np.arccos(arg_arc)*180/np.pi
        print("Theta_k =",theta_k,"  degrees")
        thetas.append(theta_k)
        if theta_k < theta_tolerance:
            break

        indices = []
        for i in range(N):
                if (psi.vec[i] < 0) and (TD_node.vec[i] > 0):#In Omega  -DJ>0 mm DJ < 0 , NOT optimal
                    indices.append(i)
                elif(psi.vec[i] > 0) and (TD_node.vec[i] < 0): #OUT Omega
                    indices.append(i)
        active_dofs.append(len(indices))
        iterations.append(k)
        print("ACTIVE DOFS",len(indices) )
        if (len(indices) < int(0.005*N)) and (k > 4) :
            print("99.5% of elements satisfy optimality conditions, non optimal elements are",len(indices) ," out of ",N )
            break



        for j in range(10):

            # update the level set function
            psinew.vec.data = (1-kappa)*psi.vec + kappa*TD_node.vec
            #psinew.vec.data = psi.vec - kappa *g_k.vec
            # update beta and f_rhs
            InterpolateLevelSetToElems(psinew, 1, 0, vol, mesh, EPS)
            InterpolateLevelSetToElems(psinew, alpha_in, alpha_out, alpha, mesh, EPS)

            # solve PDE without adjoint
            SolvePDE()

            Redraw(blocking=True)
            compliance_cf= InnerProduct ( alpha*Stress(Eps(gfu)) , Eps(gfu)   )
            J_new = Integrate(compliance_cf, mesh) + ell*Integrate(vol,mesh)

            if J_new > max_last_five:
                print("--------------------")
                print("-----line search ---")
                print("--------------------")
                kappa = kappa*0.6
                kappa = max(0.01,kappa) 
                print("kappa", kappa)
            else:
                kappa = min(kappa_max, kappa*1.2)
                print("Step accepted , size increased from " , kappa/1.2 ,"to ",kappa)                
                break


        print("end of iter " + str(k))
# Out:
# Cost before loop =  20102.1245825215
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
# ================ iteration  0 ===================
# cost in beginning of iteration 0 : Cost =  20102.12458251536
# Maximum cost in last 5 iterations =  20102.1245825215
# Theta_k = 90.00031576328689   degrees
# ACTIVE DOFS 4377
# Step accepted , size increased from  0.5 to  0.6
# end of iter 0
# ================ iteration  1 ===================
# cost in beginning of iteration 1 : Cost =  8523.458234822268
# Maximum cost in last 5 iterations =  20102.1245825215
# Theta_k = 90.0011713594952   degrees
# ACTIVE DOFS 4147
# Step accepted , size increased from  0.6 to  0.72
# end of iter 1
# ================ iteration  2 ===================
# cost in beginning of iteration 2 : Cost =  184.0269558280139
# Maximum cost in last 5 iterations =  20102.1245825215
# Theta_k = 89.8564295490709   degrees
# ACTIVE DOFS 2156
# Step accepted , size increased from  0.72 to  0.864
# end of iter 2
# ================ iteration  3 ===================
# cost in beginning of iteration 3 : Cost =  2830.284654835512
# Maximum cost in last 5 iterations =  20102.1245825215
# Theta_k = 89.99843346071563   degrees
# ACTIVE DOFS 3214
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 3
# ================ iteration  4 ===================
# cost in beginning of iteration 4 : Cost =  177.27666339782928
# Maximum cost in last 5 iterations =  20102.12458251536
# Theta_k = 89.9018260952849   degrees
# ACTIVE DOFS 1995
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 4
# ================ iteration  5 ===================
# cost in beginning of iteration 5 : Cost =  6850.571094279021
# Maximum cost in last 5 iterations =  8523.458234822268
# Theta_k = 90.0009462533167   degrees
# ACTIVE DOFS 3989
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 5
# ================ iteration  6 ===================
# cost in beginning of iteration 6 : Cost =  293.5958981118015
# Maximum cost in last 5 iterations =  6850.571094279021
# Theta_k = 90.08779225294718   degrees
# ACTIVE DOFS 4095
# --------------------
# -----line search ---
# --------------------
# kappa 0.6
# Step accepted , size increased from  0.6 to  0.72
# end of iter 6
# ================ iteration  7 ===================
# cost in beginning of iteration 7 : Cost =  1714.9111746064336
# Maximum cost in last 5 iterations =  6850.571094279021
# Theta_k = 89.99570455765239   degrees
# ACTIVE DOFS 3162
# Step accepted , size increased from  0.72 to  0.864
# end of iter 7
# ================ iteration  8 ===================
# cost in beginning of iteration 8 : Cost =  180.40001810756306
# Maximum cost in last 5 iterations =  6850.571094279021
# Theta_k = 89.87601112819469   degrees
# ACTIVE DOFS 1568
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 8
# ================ iteration  9 ===================
# cost in beginning of iteration 9 : Cost =  2934.869035692198
# Maximum cost in last 5 iterations =  6850.571094279021
# Theta_k = 89.99778439155969   degrees
# ACTIVE DOFS 2982
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 9
# ================ iteration  10 ===================
# cost in beginning of iteration 10 : Cost =  246.77133206235908
# Maximum cost in last 5 iterations =  2934.869035692198
# Theta_k = 89.97264521735205   degrees
# ACTIVE DOFS 3123
# --------------------
# -----line search ---
# --------------------
# kappa 0.6
# Step accepted , size increased from  0.6 to  0.72
# end of iter 10
# ================ iteration  11 ===================
# cost in beginning of iteration 11 : Cost =  2657.3756046124704
# Maximum cost in last 5 iterations =  2934.869035692198
# Theta_k = 89.99724752654426   degrees
# ACTIVE DOFS 3429
# Step accepted , size increased from  0.72 to  0.864
# end of iter 11
# ================ iteration  12 ===================
# cost in beginning of iteration 12 : Cost =  176.89548264937775
# Maximum cost in last 5 iterations =  2934.869035692198
# Theta_k = 89.8848895713804   degrees
# ACTIVE DOFS 1975
# --------------------
# -----line search ---
# --------------------
# kappa 0.5184
# Step accepted , size increased from  0.5184 to  0.62208
# end of iter 12
# ================ iteration  13 ===================
# cost in beginning of iteration 13 : Cost =  2485.006425682029
# Maximum cost in last 5 iterations =  2934.869035692198
# Theta_k = 89.99729059769528   degrees
# ACTIVE DOFS 3038
# Step accepted , size increased from  0.62208 to  0.7464959999999999
# end of iter 13
# ================ iteration  14 ===================
# cost in beginning of iteration 14 : Cost =  160.0166465939995
# Maximum cost in last 5 iterations =  2657.3756046124704
# Theta_k = 89.87264868645958   degrees
# ACTIVE DOFS 1373
# Step accepted , size increased from  0.7464959999999999 to  0.8957951999999999
# end of iter 14
# ================ iteration  15 ===================
# cost in beginning of iteration 15 : Cost =  1799.2362320869465
# Maximum cost in last 5 iterations =  2657.3756046124704
# Theta_k = 89.99555890041616   degrees
# ACTIVE DOFS 2609
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 15
# ================ iteration  16 ===================
# cost in beginning of iteration 16 : Cost =  174.7576765758655
# Maximum cost in last 5 iterations =  2485.006425682029
# Theta_k = 89.89296544670931   degrees
# ACTIVE DOFS 1674
# --------------------
# -----line search ---
# --------------------
# kappa 0.6
# Step accepted , size increased from  0.6 to  0.72
# end of iter 16
# ================ iteration  17 ===================
# cost in beginning of iteration 17 : Cost =  1593.2480758742436
# Maximum cost in last 5 iterations =  2485.006425682029
# Theta_k = 89.9943868467137   degrees
# ACTIVE DOFS 2480
# Step accepted , size increased from  0.72 to  0.864
# end of iter 17
# ================ iteration  18 ===================
# cost in beginning of iteration 18 : Cost =  158.12289669432963
# Maximum cost in last 5 iterations =  1799.2362320869465
# Theta_k = 89.87998728018293   degrees
# ACTIVE DOFS 1196
# --------------------
# -----line search ---
# --------------------
# kappa 0.5184
# Step accepted , size increased from  0.5184 to  0.62208
# end of iter 18
# ================ iteration  19 ===================
# cost in beginning of iteration 19 : Cost =  1517.4313597126816
# Maximum cost in last 5 iterations =  1799.2362320869465
# Theta_k = 89.99388944281225   degrees
# ACTIVE DOFS 2032
# Step accepted , size increased from  0.62208 to  0.7464959999999999
# end of iter 19
# ================ iteration  20 ===================
# cost in beginning of iteration 20 : Cost =  149.03715784812115
# Maximum cost in last 5 iterations =  1593.2480758742436
# Theta_k = 89.85646550792039   degrees
# ACTIVE DOFS 979
# --------------------
# -----line search ---
# --------------------
# kappa 0.44789759999999995
# Step accepted , size increased from  0.44789759999999995 to  0.5374771199999999
# end of iter 20
# ================ iteration  21 ===================
# cost in beginning of iteration 21 : Cost =  231.21422753857854
# Maximum cost in last 5 iterations =  1593.2480758742436
# Theta_k = 89.98217229563613   degrees
# ACTIVE DOFS 633
# Step accepted , size increased from  0.5374771199999999 to  0.6449725439999999
# end of iter 21
# ================ iteration  22 ===================
# cost in beginning of iteration 22 : Cost =  141.7883444824151
# Maximum cost in last 5 iterations =  1517.4313597126816
# Theta_k = 89.86203080019696   degrees
# ACTIVE DOFS 377
# Step accepted , size increased from  0.6449725439999999 to  0.7739670527999999
# end of iter 22
# ================ iteration  23 ===================
# cost in beginning of iteration 23 : Cost =  121.93667586544854
# Maximum cost in last 5 iterations =  1517.4313597126816
# Theta_k = 89.81570714838793   degrees
# ACTIVE DOFS 176
# Step accepted , size increased from  0.7739670527999999 to  0.9287604633599998
# end of iter 23
# ================ iteration  24 ===================
# cost in beginning of iteration 24 : Cost =  117.83179689578813
# Maximum cost in last 5 iterations =  231.21422753857854
# Theta_k = 89.80746178945095   degrees
# ACTIVE DOFS 68
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 24
# ================ iteration  25 ===================
# cost in beginning of iteration 25 : Cost =  117.05013432452753
# Maximum cost in last 5 iterations =  231.21422753857854
# Theta_k = 89.80913169075147   degrees
# ACTIVE DOFS 42
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 25
# ================ iteration  26 ===================
# cost in beginning of iteration 26 : Cost =  116.96821716584223
# Maximum cost in last 5 iterations =  141.7883444824151
# Theta_k = 89.80880961010963   degrees
# ACTIVE DOFS 29
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 26
# ================ iteration  27 ===================
# cost in beginning of iteration 27 : Cost =  117.02170477750562
# Maximum cost in last 5 iterations =  121.93667586544854
# Theta_k = 89.80822534610888   degrees
# ACTIVE DOFS 35
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 27
# ================ iteration  28 ===================
# cost in beginning of iteration 28 : Cost =  118.03175944582759
# Maximum cost in last 5 iterations =  118.03175944582759
# Theta_k = 89.81077847495106   degrees
# ACTIVE DOFS 46
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 28
# ================ iteration  29 ===================
# cost in beginning of iteration 29 : Cost =  117.3942108880919
# Maximum cost in last 5 iterations =  118.03175944582759
# Theta_k = 89.80746395619029   degrees
# ACTIVE DOFS 39
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 29
# ================ iteration  30 ===================
# cost in beginning of iteration 30 : Cost =  116.91754391741199
# Maximum cost in last 5 iterations =  118.03175944582759
# Theta_k = 89.80585612579722   degrees
# ACTIVE DOFS 27
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 30
# ================ iteration  31 ===================
# cost in beginning of iteration 31 : Cost =  116.72742466504897
# Maximum cost in last 5 iterations =  118.03175944582759
# Theta_k = 89.80496043664996   degrees
# ACTIVE DOFS 27
# Step accepted , size increased from  0.8333333333333334 to  1
# end of iter 31
# ================ iteration  32 ===================
# cost in beginning of iteration 32 : Cost =  116.68999634433906
# Maximum cost in last 5 iterations =  118.03175944582759
# Theta_k = 89.80401431755023   degrees
# ACTIVE DOFS 21
# 99.5% of elements satisfy optimality conditions, non optimal elements are 21  out of  4586

# %%
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt# Figure 1: Norm vs Iteration
plt.figure()
plt.plot(iterations, active_dofs, label='Active Dofs')
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('Active Dofs', fontsize=14)
plt.title('Count of non-optimal DOFs vs Iteration', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend()
plt.grid(True)
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.savefig("active_dofs_bridge_triple_conv_REF_circ.png")
plt.show()

# %%
import matplotlib.pyplot as plt# Figure 1: Norm vs Iteration
plt.plot(iterations, thetas, label='Theta')
plt.xlabel('Iteration',fontsize=14)
plt.ylabel('Theta',fontsize=14)
plt.title('Theta criterion vs Iteration',fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend()
plt.grid(True)
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.savefig("theta_bridge_triple_conv_REF_circ.png")
plt.show()
